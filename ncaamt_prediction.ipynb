# %%
import pandas as pd

# %%
ncaamt = pd.read_csv('resources/KPB.csv')

# %%
ncaamt.drop(['CONF ID', 'TEAM NO'], axis=1, inplace=True)

# %%
ncaamt.drop(['QUAD NO', 'QUAD ID', 'K TEMPO', 'K TEMPO RANK'], axis=1, inplace=True)

# %%
ncaamt.drop(['KADJ T', 'KADJ T RANK', 'BADJT RANK', 'EXP RANK', 'TALENT RANK'], axis=1, inplace=True)

# %%
ncaamt.drop(['KADJ O', 'KADJ O RANK', 'K OFF', 'KO RANK'], axis=1, inplace=True)

# %%
ncaamt.drop(['KADJ D', 'KADJ D RANK', 'K DEF', 'KD RANK'], axis=1, inplace=True)

# %%
ncaamt.drop(['KADJ EM', 'KADJ EM RANK', 'BADJ EM', 'BADJ O'], axis=1, inplace=True)

# %%
ncaamt.drop(['BADJ D', 'BARTHAG'], axis=1, inplace=True)

# %%
ncaamt.drop(['3PTR RANK', '2PTRD RANK', '3PTRD RANK', 'AVG HGT RANK', 'EFF HGT RANK', 'FT% RANK', 'OP FT% RANK'], axis=1, inplace=True)

# %%
ncaamt.drop(['3PT% RANK', '3PT%D RANK', 'BLK% RANK', 'BLKED% RANK', 'AST% RANK', 'OP AST% RANK', '2PTR RANK'], axis=1, inplace=True)

# %%
ncaamt.drop(['OREB% RANK', 'DREB% RANK', 'OP OREB% RANK', 'OP DREB% RANK', 'RAW T RANK', '2PT% RANK', '2PT%D RANK'], axis=1, inplace=True)

# %%
ncaamt.drop(['BARTHAG RANK', 'EFG% RANK', 'EFGD% RANK', 'FTR RANK', 'FTRD RANK', 'TOV% RANK', 'TOV%D RANK'], axis=1, inplace=True)

# %%
ncaamt.drop(['BADJ EM RANK', 'BADJ O RANK', 'BADJ D RANK', 'PPPO RANK', 'PPPD RANK', 'ELITE SOS RANK'], axis=1, inplace=True)

# %%
ncaamt.drop(['TALENT', 'EXP', 'ELITE SOS'], axis=1, inplace=True)

# %%
ncaamt.drop(['BADJ T'], axis=1, inplace=True)

# %%
ncaamt.drop(['W', 'L'], axis=1, inplace=True)

# %%
ncaamt.drop(['GAMES'], axis=1, inplace=True)

# %%
ncaamt.drop(['AVG HGT', 'EFF HGT', 'PPPO', 'PPPD'], axis=1, inplace=True)

# %%
ncaamt.drop(['WAB'], axis=1, inplace=True)

# %%
ncaamt.drop(['TEAM ID'], axis=1, inplace=True)

# %%
ncaamt
# Out:
#       YEAR  CONF              TEAM  SEED  ROUND       WIN%  EFG%  EFG%D   FTR  \
# 0     2024   MAC             Akron    14      0  68.750000  52.0   48.6  33.6
# 1     2024   SEC           Alabama     4      0  65.625000  56.3   49.9  35.2
# 2     2024   P12           Arizona     2      0  75.757576  55.0   48.7  36.7
# 3     2024   SEC            Auburn     4      0  79.411765  54.1   43.4  38.2
# 4     2024   B12            Baylor     3      0  68.750000  55.6   51.3  40.5
# ...    ...   ...               ...   ...    ...        ...   ...    ...   ...
# 1074  2008    BE     West Virginia     7     16  69.696970  51.6   47.7  37.1
# 1075  2008    SB  Western Kentucky    12     16  80.645160  53.6   46.9  36.2
# 1076  2008  BSth          Winthrop    13     64  64.516130  50.0   46.1  36.3
# 1077  2008   B10         Wisconsin     3     16  87.878790  50.6   43.1  39.3
# 1078  2008   A10            Xavier     3      8  81.818180  55.0   46.8  41.7
#
# ...

# %%
columns = list(ncaamt.columns)
columns
# Out:
# ['YEAR',
#  'CONF',
#  'TEAM',
#  'SEED',
#  'ROUND',
#  'WIN%',
#  'EFG%',
#  'EFG%D',
#  'FTR',
#  'FTRD',
#  'TOV%',
#  'TOV%D',
#  'OREB%',
#  'DREB%',
#  'OP OREB%',
#  'OP DREB%',
#  'RAW T',
#  '2PT%',
#  '2PT%D',
#  '3PT%',
#  '3PT%D',
#  'BLK%',
#  'BLKED%',
#  'AST%',
#  'OP AST%',
#  '2PTR',
#  '3PTR',
#  '2PTRD',
#  '3PTRD',
#  'FT%',
#  'OP FT%']

# %%
ncaamt['nEFG'] = ncaamt['EFG%'] - ncaamt['EFG%D']

# %%
ncaamt.drop(['EFG%', 'EFG%D'], axis=1, inplace=True)

# %%
ncaamt['nFTR'] = ncaamt['FTR'] - ncaamt['FTRD']

# %%
ncaamt.drop(['FTR', 'FTRD'], axis=1, inplace=True)

# %%
ncaamt['nTOV'] = ncaamt['TOV%'] - ncaamt['TOV%D']

# %%
ncaamt.drop(['TOV%', 'TOV%D'], axis=1, inplace=True)

# %%
ncaamt['nREB'] = ncaamt['OREB%'] - ncaamt['DREB%']

# %%
ncaamt.drop(['OREB%', 'DREB%'], axis=1, inplace=True)

# %%
ncaamt['nOpREB'] = ncaamt['OP OREB%'] - ncaamt['OP DREB%']

# %%
ncaamt.drop(['OP OREB%', 'OP DREB%'], axis=1, inplace=True)

# %%
ncaamt.drop(['RAW T'], axis=1, inplace=True)

# %%
ncaamt.drop(['nOpREB'], axis=1, inplace=True)

# %%
ncaamt['n2PT'] = ncaamt['2PT%'] - ncaamt['2PT%D']

# %%
ncaamt.drop(['2PT%', '2PT%D'], axis=1, inplace=True)

# %%
ncaamt['n3PT'] = ncaamt['3PT%'] - ncaamt['3PT%D']

# %%
ncaamt.drop(['3PT%', '3PT%D'], axis=1, inplace=True)

# %%
ncaamt['nBLK'] = ncaamt['BLK%'] - ncaamt['BLKED%']

# %%
ncaamt.drop(['BLK%', 'BLKED%'], axis=1, inplace=True)

# %%
ncaamt['nAST'] = ncaamt['AST%'] - ncaamt['OP AST%']

# %%
ncaamt.drop(['AST%', 'OP AST%'], axis=1, inplace=True)

# %%
ncaamt['n2PTR'] = ncaamt['2PTR'] - ncaamt['2PTRD']

# %%
ncaamt.drop(['2PTR', '2PTRD'], axis=1, inplace=True)

# %%
ncaamt['n3PTR'] = ncaamt['3PTR'] - ncaamt['3PTRD']

# %%
ncaamt.drop(['3PTR', '3PTRD'], axis=1, inplace=True)

# %%
ncaamt['nFT'] = ncaamt['FT%'] - ncaamt['OP FT%']

# %%
ncaamt.drop(['FT%', 'OP FT%'], axis=1, inplace=True)

# %%
ncaamt.drop(['n2PTR', 'n3PTR'], axis=1, inplace=True)

# %%
ncaamt
# Out:
#       YEAR  CONF              TEAM  SEED  ROUND       WIN%  nEFG  nFTR  nTOV  \
# 0     2024   MAC             Akron    14      0  68.750000   3.4   4.6   0.6
# 1     2024   SEC           Alabama     4      0  65.625000   6.4  -4.4   0.4
# 2     2024   P12           Arizona     2      0  75.757576   6.3  11.0  -2.0
# 3     2024   SEC            Auburn     4      0  79.411765  10.7  -2.8  -3.3
# 4     2024   B12            Baylor     3      0  68.750000   4.3   9.6   0.6
# ...    ...   ...               ...   ...    ...        ...   ...   ...   ...
# 1074  2008    BE     West Virginia     7     16  69.696970   3.9  -1.8  -7.0
# 1075  2008    SB  Western Kentucky    12     16  80.645160   6.7 -11.5  -5.0
# 1076  2008  BSth          Winthrop    13     64  64.516130   3.9   2.5  -3.4
# 1077  2008   B10         Wisconsin     3     16  87.878790   7.5  13.9  -2.8
# 1078  2008   A10            Xavier     3      8  81.818180   8.2  10.2   0.3
#
#       nREB  n2PT  n3PT  nBLK  nAST  nFT
# ...

# %%
ncaamt['SEED'].unique
# Out:
# <bound method Series.unique of 0       14
# 1        4
# 2        2
# 3        4
# 4        3
#         ..
# 1074     7
# 1075    12
# 1076    13
# 1077     3
# 1078     3
# Name: SEED, Length: 1079, dtype: int64>

# %%
ncaamt.dtypes
# Out:
# YEAR       int64
# CONF      object
# TEAM      object
# SEED       int64
# ROUND      int64
# WIN%     float64
# nEFG     float64
# nFTR     float64
# nTOV     float64
# nREB     float64
# n2PT     float64
# n3PT     float64
# nBLK     float64
# nAST     float64
# nFT      float64
# dtype: object

# %%
ncaamt = ncaamt[ncaamt['YEAR'] != 2024]

# %%
ncaamt
# Out:
#       YEAR  CONF              TEAM  SEED  ROUND       WIN%  nEFG  nFTR  nTOV  \
# 68    2023   SEC           Alabama     1     16  85.294118  11.2   3.9   3.1
# 69    2023   P12           Arizona     2     64  82.352941   9.6  10.5   1.5
# 70    2023   P12       Arizona St.    11     64  64.705882   1.1  -2.6  -3.7
# 71    2023   SEC          Arkansas     8     16  60.606061   5.5  -0.1  -2.1
# 72    2023   SEC            Auburn     9     32  62.500000   4.0  -3.6  -1.2
# ...    ...   ...               ...   ...    ...        ...   ...   ...   ...
# 1074  2008    BE     West Virginia     7     16  69.696970   3.9  -1.8  -7.0
# 1075  2008    SB  Western Kentucky    12     16  80.645160   6.7 -11.5  -5.0
# 1076  2008  BSth          Winthrop    13     64  64.516130   3.9   2.5  -3.4
# 1077  2008   B10         Wisconsin     3     16  87.878790   7.5  13.9  -2.8
# 1078  2008   A10            Xavier     3      8  81.818180   8.2  10.2   0.3
#
#       nREB  n2PT  n3PT  nBLK  nAST  nFT
# ...

# %%
ncaamt.describe()
# Out:
#               YEAR         SEED        ROUND         WIN%         nEFG  \
# count  1011.000000  1011.000000  1011.000000  1011.000000  1011.000000
# mean   2015.255193     8.768546    43.949555    72.482880     4.670623
# std       4.591874     4.673269    22.906794     9.963028     3.312188
# min    2008.000000     1.000000     1.000000    36.666670    -7.400000
# 25%    2011.000000     5.000000    32.000000    65.625000     2.400000
# 50%    2015.000000     9.000000    64.000000    72.727270     4.600000
# 75%    2019.000000    13.000000    64.000000    78.787880     6.800000
# max    2023.000000    16.000000    68.000000   100.000000    16.400000
#
#               nFTR         nTOV         nREB         n2PT         n3PT  \
# count  1011.000000  1011.000000  1011.000000  1011.000000  1011.000000
# mean      3.788823    -1.650247   -38.203858     4.777349     2.931751
# std       6.621056     2.880623     6.046884     3.925526     3.123737
# ...
